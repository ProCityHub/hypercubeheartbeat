# %% [markdown]
# <a href="https://www.kaggle.com/code/adrienthomas/google-deepmind-vibe-code-with-gemini-3-pro-in-a?scriptVersionId=294625902" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/gemini-3/README
# /kaggle/input/ara-complete-master/grok_report (12).pdf
# /kaggle/input/ara-complete-master/grok_report (14).pdf
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/index.tsx
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/App.tsx
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/manifest.json
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/.gitignore
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/README.md
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/metadata.json
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/.env.local
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/service-worker.js
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/types.ts
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/vite.config.ts
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/tsconfig.json
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/index.html
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/package.json
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/services/storageService.ts
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/services/geminiService.ts
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/components/icons.tsx
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/components/CommandBar.tsx
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/components/Codex.tsx
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/components/SavedDirectivesList.tsx
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/components/FormProcessor.tsx
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/components/Window.tsx
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/components/AegisCommand.tsx
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/components/SystemAnatomy.tsx
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/components/EnterpriseWorkspace.tsx
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/components/LoadingIndicator.tsx
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/components/NexusBrowser.tsx
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/components/InvoiceEditor.tsx
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/components/StartMenu.tsx
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/components/TopicInput.tsx
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/components/SystemIntel.tsx
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/components/Taskbar.tsx
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/components/Dashboard.tsx
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/components/BusinessEnterprise.tsx
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/components/SkeletonLoader.tsx
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/components/NexusForge.tsx
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/components/AuthScreen.tsx
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/components/formTypes.ts
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/components/BitcoinMiner.tsx
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/components/FileExplorer.tsx
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/components/FinanceWorkspace.tsx
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/components/UserAccounts.tsx
# /kaggle/input/ara-complete-master/garvis_-generative-ai-research-visualization-and-innovations-system (4)/components/DesktopIcon.tsx
# /kaggle/input/ara-complete-master/files/SAMPLE_OUTPUT.txt
# /kaggle/input/ara-complete-master/files/README.md
# /kaggle/input/ara-complete-master/files/IMPLEMENTATION_GUIDE.md
# /kaggle/input/ara-complete-master/files/MATHEMATICAL_FOUNDATION.md
# /kaggle/input/ara-complete-master/files/ARA_COMPLETE.py
# /kaggle/input/ara-complete-master/files/test_suite.py
# /kaggle/input/ara-complete-master/files/STRESS_TEST_RESULTS.md
# /kaggle/input/ara-complete-master/files/convergence_metrics.json
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/README.md
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/decode_and_run.py
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/LICENSE.txt
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/tests/test_all.py
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/core/timing_identity.py
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/core/quantum_integration.py
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/core/artifact_math.py
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/core/hypercube.py
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/core/hidden_variable.py
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/docs/INTEGRATION_QUANTUM.md
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/viz/propagate_plot.py
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/viz/ascii_viewer.py
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/engine/lattice.py
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/engine/unifier.py
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/engine/cube_expand.py
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/engine/propagate.py
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/engine/agi_interpreter.py
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/binary_src/test_all.py.bin
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/binary_src/propagate_plot.py.bin
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/binary_src/unifier.py.bin
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/binary_src/agi_interpreter.py.bin
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/binary_src/propagate.py.bin
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/binary_src/cube_expand.py.bin
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/binary_src/quantum_integration.py.bin
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/binary_src/LICENSE.txt.bin
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/binary_src/artifact_math.py.bin
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/binary_src/lattice.py.bin
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/binary_src/README.md.bin
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/binary_src/hidden_variable.py.bin
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/binary_src/timing_identity.py.bin
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/binary_src/hypercube.py.bin
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/binary_src/INTEGRATION_QUANTUM.md.bin
# /kaggle/input/ara-complete-master/hypercube-genesis/hypercube-genesis/binary_src/ascii_viewer.py.bin
